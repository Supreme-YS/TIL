# %%
from IPython.display import Image
Image('c:/cnn_img/cnn01.jpg', width = 700)

# %%
Image('c:/cnn_img/cnn02.jpg', width = 700)

# %%
Image('c:/cnn_img/cnn03.jpg', width = 700)

# %%
Image('c:/cnn_img/cnn06.jpg', width = 700)

# %%
Image('c:/cnn_img/cnn08.jpg', width = 700)

# %% [markdown]
# - 이미지 , 영상, 텍스트 , 음성
# - CNN(Convolutional Neural Networks) - 합성곱 신경망
# - 이미지 데이터는 픽셀(R,G,B)
# - 28 * 28 * 1
# - 28 * 28 * 3
# - img = image.img_to_array(img)
# - img.shape

# %%
Image('c:/cnn_img/cnn15.jpg', width = 700)

# %%
Image('c:/cnn_img/cnn11.jpg', width = 700)

# %%
Image('c:/cnn_img/cnn16.jpg', width = 700)

# %%
Image('c:/cnn_img/cnn17.jpg', width = 700)

# %%
Image('c:/cnn_img/cnn24.jpg', width = 700)

# %%
Image('c:/cnn_img/cnn30.jpg', width = 700)

# %%
Image('c:/cnn_img/cnn32.jpg', width = 700)

# %%
Image('c:/cnn_img/cnn34.jpg', width = 700)
