# %% [markdown]
# #### Ensemble 학습
# - 보팅(Voting)   : 같은 데이터 세트를 이용하고 서로 다른 분류 알고리즘을 활용해서 최종 예측
# - 배깅(Bagging)  : 데이터 샘플링을 통해서 서브세트를 만들고 같은 분류 알고리즘을 활용해서 최종 예측
# -
# - 보팅 유형 : 하드 보팅(다수결) vs 소트프 보팅(확률)
# - 배깅 유형 : 랜덤 포레스트(DecisionTreeClassifier) -> 확률

# %%
from sklearn.tree         import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# SVM add
from sklearn.svm          import SVC

# Knn add
from sklearn.neighbors    import KNeighborsClassifier

# ensemble add
from sklearn.ensemble     import VotingClassifier
from sklearn.ensemble     import RandomForestClassifier



from sklearn.preprocessing   import LabelEncoder , OneHotEncoder , StandardScaler , MinMaxScaler , Binarizer 
from sklearn.model_selection import train_test_split , GridSearchCV , cross_val_score

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score , roc_auc_score
from sklearn.metrics import confusion_matrix, precision_recall_curve , roc_curve

import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sns

import missingno as ms
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# datasets
from sklearn.datasets import load_breast_cancer

# %% [markdown]
# #### Voting Classifier

# %%
cancer = load_breast_cancer()
cancer.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
cancerDF = pd.DataFrame(cancer.data , 
                        columns = cancer.feature_names)
cancerDF.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
from IPython.display import Image
Image('c:/img/ensemble-01.png', width = 700)

# %%
Image('c:/img/ensemble-02.png', width = 700)

# %%
# 소프트 보팅
# 앙상블 구현을 위해서 분류 모델 선정(tree , logistic , knn , svm )
# 앙상블 모델을 만들고
# 데이터 세트 분리

# 보팅을 통해서 학습/예측/평가
# 최종적으로 시각화를 진행

# [실습]

# %% [markdown]
# #### Voting 연습

# %%
from sklearn.datasets import load_digits

# %%
mnist = load_digits()
# mnist.keys()
features , labels = mnist.data , mnist.target

# %%
features.shape
# Out:
# (1797, 64)

# %%
labels.shape
# Out:
# (1797,)

# %%
X_train , X_test , y_train , y_test = train_test_split(features , labels , test_size=0.2 , random_state=100)

# %%
# AUC 성능평가 확인

def metrics_evaluation(y_test, y_pred=None , y_pred_proba=None) :
    print("정확도 : {} , 정밀도 : {} , 재현율 : {} , 조화평균(F1) : {} , AUC : {} "
          .format(accuracy_score(y_test, y_pred) , 
                  precision_score(y_test, y_pred) , 
                  recall_score(y_test, y_pred) , 
                  f1_score(y_test, y_pred) , 
                  roc_auc_score(y_test, y_pred_proba) ) )

# %%
dt = DecisionTreeClassifier(criterion='entropy' , 
                            max_depth = 8 , 
                            max_features=32 , 
                            random_state=35 ) 
dt.fit(X_train , y_train)
dt_pred = dt.predict(X_test)

knn = KNeighborsClassifier(n_neighbors = 299) 
knn.fit(X_train , y_train)
knn_pred = knn.predict(X_test)


svm = SVC(probability=True) 
svm.fit(X_train , y_train)
svm_pred = svm.predict(X_test)

# %%
# print('target : ' , y_test)
# print('prediction : ' , dt_pred)
print('tree : ' , accuracy_score(y_test , dt_pred))
print('knn : '  , accuracy_score(y_test ,  knn_pred))
print('svm : ' , accuracy_score(y_test , svm_pred))
# Out:
# tree :  0.8694444444444445
# knn :  0.8555555555555555
# svm :  0.9916666666666667

# %%
voting_clf = VotingClassifier(estimators = [ ('tree' , dt) , ('knn' , knn) , ('svm' , svm) ]  , 
                              weights = [1,1,1] , 
                              voting  = 'hard')
voting_clf.fit(X_train , y_train)
hard_voting_pred = voting_clf.predict(X_test)
print('hard voting : ' , accuracy_score(y_test , hard_voting_pred))
# Out:
# hard voting :  0.9611111111111111

# %%
voting_clf = VotingClassifier(estimators = [ ('tree' , dt) , ('knn' , knn) , ('svm' , svm) ]  , 
                              weights = [1,1,1] , 
                              voting  = 'soft')
voting_clf.fit(X_train , y_train)
soft_voting_pred = voting_clf.predict(X_test)
print('sotf voting : ' , accuracy_score(y_test , soft_voting_pred ))
# Out:
# sotf voting :  0.9361111111111111

# %% [markdown]
# #### Visualization

# %%
plt.figure(figsize=(15, 5))

x = np.arange(5)

plt.bar(x , height = [ accuracy_score(y_test , dt_pred)   ,
                       accuracy_score(y_test ,  knn_pred) , 
                       accuracy_score(y_test ,  svm_pred) ,
                       accuracy_score(y_test , hard_voting_pred) , 
                       accuracy_score(y_test , soft_voting_pred)])

plt.xticks(x , ['tree' , 'knn' , 'svm' , 'hard' , 'soft'])
plt.show()
plt.close()

# %% [markdown]
# #### bagging - Random Forest(DecisionTree)

# %% [markdown]
# - bagging 연습

# %% [markdown]
# - 1. load mnist dataset

# %%
mnist = load_digits()
# mnist.keys()
features , labels = mnist.data , mnist.target

# %% [markdown]
# - 2. Cross Validation

# %%
def user_cross_validation(classifier , features , labels) :
    cv_scores = []
    
    for i in range(10) :
        scores = cross_val_score(classifier , features , labels , cv=10 , scoring='accuracy')
        cv_scores.append( scores.mean() ) 
    
    return cv_scores

# %%
dt_cv_scores = user_cross_validation(DecisionTreeClassifier() , features , labels)
rt_cv_scores = user_cross_validation(RandomForestClassifier() , features , labels)

# %%
dt_cv_scores
np.mean(dt_cv_scores)
# Out:
# 0.8247504655493483

# %%
rt_cv_scores
np.mean(rt_cv_scores)
# Out:
# 0.9483531967721911

# %% [markdown]
# - Decision Tree vs Random Forest Visualization

# %%
cv_list = [
    ['decision' , dt_cv_scores],
    ['random forest' , rt_cv_scores]
]

# %%
visualDF = pd.DataFrame.from_dict(dict(cv_list))
visualDF
# Out:
#    decision  random forest
# 0  0.832483       0.951034
# 1  0.821381       0.948240
# 2  0.818011       0.946577
# 3  0.827480       0.948234
# 4  0.828591       0.946018
# 5  0.823579       0.950472
# 6  0.823582       0.947691
# 7  0.821344       0.945459
# 8  0.823569       0.951561
# 9  0.827486       0.948246

# %%
visualDF.plot()
# Out:
# <AxesSubplot:>

# %%
pd.__version__
# Out:
# '1.1.3'

# %% [markdown]
# #### Voting  & Bagging 실전

# %%
# 각 데이터 파일들은 공백으로 분리되어 있으므로 read_csv에서 공백문자를 sep으로 할당
# features.txt
# sep='\s+'

features = pd.read_csv('./data/human_activity/features.txt',
                        sep='\s+',
                        header=None, 
                        names=['column_name'])
features
# Out:
#                          column_name
# 0                    tBodyAcc-Mean-1
# 1                    tBodyAcc-Mean-2
# 2                    tBodyAcc-Mean-3
# 3                     tBodyAcc-STD-1
# 4                     tBodyAcc-STD-2
# 5                     tBodyAcc-STD-3
# 6                     tBodyAcc-Mad-1
# 7                     tBodyAcc-Mad-2
# 8                     tBodyAcc-Mad-3
# 9                     tBodyAcc-Max-1
# 10                    tBodyAcc-Max-2
# 11                    tBodyAcc-Max-3
# 12                    tBodyAcc-Min-1
# 13                    tBodyAcc-Min-2
# 14                    tBodyAcc-Min-3
# 15                    tBodyAcc-SMA-1
# 16                 tBodyAcc-Energy-1
# 17                 tBodyAcc-Energy-2
# 18                 tBodyAcc-Energy-3
# 19                    tBodyAcc-IQR-1
# 20                    tBodyAcc-IQR-2
# 21                    tBodyAcc-IQR-3
# 22                   tBodyAcc-ropy-1
# 23                   tBodyAcc-ropy-1
# 24                   tBodyAcc-ropy-1
# 25                tBodyAcc-ARCoeff-1
# 26                tBodyAcc-ARCoeff-2
# 27                tBodyAcc-ARCoeff-3
# 28                tBodyAcc-ARCoeff-4
# 29                tBodyAcc-ARCoeff-5
# 30                tBodyAcc-ARCoeff-6
# 31                tBodyAcc-ARCoeff-7
# 32                tBodyAcc-ARCoeff-8
# 33                tBodyAcc-ARCoeff-9
# 34               tBodyAcc-ARCoeff-10
# 35               tBodyAcc-ARCoeff-11
# 36               tBodyAcc-ARCoeff-12
# 37            tBodyAcc-Correlation-1
# 38            tBodyAcc-Correlation-2
# 39            tBodyAcc-Correlation-3
# 40                tGravityAcc-Mean-1
# 41                tGravityAcc-Mean-2
# 42                tGravityAcc-Mean-3
# 43                 tGravityAcc-STD-1
# 44                 tGravityAcc-STD-2
# 45                 tGravityAcc-STD-3
# 46                 tGravityAcc-Mad-1
# 47                 tGravityAcc-Mad-2
# 48                 tGravityAcc-Mad-3
# 49                 tGravityAcc-Max-1
# 50                 tGravityAcc-Max-2
# 51                 tGravityAcc-Max-3
# 52                 tGravityAcc-Min-1
# 53                 tGravityAcc-Min-2
# 54                 tGravityAcc-Min-3
# 55                 tGravityAcc-SMA-1
# 56              tGravityAcc-Energy-1
# 57              tGravityAcc-Energy-2
# 58              tGravityAcc-Energy-3
# 59                 tGravityAcc-IQR-1
# 60                 tGravityAcc-IQR-2
# 61                 tGravityAcc-IQR-3
# 62                tGravityAcc-ropy-1
# 63                tGravityAcc-ropy-1
# 64                tGravityAcc-ropy-1
# 65             tGravityAcc-ARCoeff-1
# 66             tGravityAcc-ARCoeff-2
# 67             tGravityAcc-ARCoeff-3
# 68             tGravityAcc-ARCoeff-4
# 69             tGravityAcc-ARCoeff-5
# 70             tGravityAcc-ARCoeff-6
# 71             tGravityAcc-ARCoeff-7
# 72             tGravityAcc-ARCoeff-8
# 73             tGravityAcc-ARCoeff-9
# 74            tGravityAcc-ARCoeff-10
# 75            tGravityAcc-ARCoeff-11
# 76            tGravityAcc-ARCoeff-12
# 77         tGravityAcc-Correlation-1
# 78         tGravityAcc-Correlation-2
# 79         tGravityAcc-Correlation-3
# 80               tBodyAccJerk-Mean-1
# 81               tBodyAccJerk-Mean-2
# 82               tBodyAccJerk-Mean-3
# 83                tBodyAccJerk-STD-1
# 84                tBodyAccJerk-STD-2
# 85                tBodyAccJerk-STD-3
# 86                tBodyAccJerk-Mad-1
# 87                tBodyAccJerk-Mad-2
# 88                tBodyAccJerk-Mad-3
# 89                tBodyAccJerk-Max-1
# 90                tBodyAccJerk-Max-2
# 91                tBodyAccJerk-Max-3
# 92                tBodyAccJerk-Min-1
# 93                tBodyAccJerk-Min-2
# 94                tBodyAccJerk-Min-3
# 95                tBodyAccJerk-SMA-1
# 96             tBodyAccJerk-Energy-1
# 97             tBodyAccJerk-Energy-2
# 98             tBodyAccJerk-Energy-3
# 99                tBodyAccJerk-IQR-1
# 100               tBodyAccJerk-IQR-2
# 101               tBodyAccJerk-IQR-3
# 102              tBodyAccJerk-ropy-1
# 103              tBodyAccJerk-ropy-1
# 104              tBodyAccJerk-ropy-1
# 105           tBodyAccJerk-ARCoeff-1
# 106           tBodyAccJerk-ARCoeff-2
# 107           tBodyAccJerk-ARCoeff-3
# 108           tBodyAccJerk-ARCoeff-4
# 109           tBodyAccJerk-ARCoeff-5
# 110           tBodyAccJerk-ARCoeff-6
# 111           tBodyAccJerk-ARCoeff-7
# 112           tBodyAccJerk-ARCoeff-8
# 113           tBodyAccJerk-ARCoeff-9
# 114          tBodyAccJerk-ARCoeff-10
# 115          tBodyAccJerk-ARCoeff-11
# 116          tBodyAccJerk-ARCoeff-12
# 117       tBodyAccJerk-Correlation-1
# 118       tBodyAccJerk-Correlation-2
# 119       tBodyAccJerk-Correlation-3
# 120                 tBodyGyro-Mean-1
# 121                 tBodyGyro-Mean-2
# 122                 tBodyGyro-Mean-3
# 123                  tBodyGyro-STD-1
# 124                  tBodyGyro-STD-2
# 125                  tBodyGyro-STD-3
# 126                  tBodyGyro-Mad-1
# 127                  tBodyGyro-Mad-2
# 128                  tBodyGyro-Mad-3
# 129                  tBodyGyro-Max-1
# 130                  tBodyGyro-Max-2
# 131                  tBodyGyro-Max-3
# 132                  tBodyGyro-Min-1
# 133                  tBodyGyro-Min-2
# 134                  tBodyGyro-Min-3
# 135                  tBodyGyro-SMA-1
# 136               tBodyGyro-Energy-1
# 137               tBodyGyro-Energy-2
# 138               tBodyGyro-Energy-3
# 139                  tBodyGyro-IQR-1
# 140                  tBodyGyro-IQR-2
# 141                  tBodyGyro-IQR-3
# 142                 tBodyGyro-ropy-1
# 143                 tBodyGyro-ropy-1
# 144                 tBodyGyro-ropy-1
# 145              tBodyGyro-ARCoeff-1
# 146              tBodyGyro-ARCoeff-2
# 147              tBodyGyro-ARCoeff-3
# 148              tBodyGyro-ARCoeff-4
# 149              tBodyGyro-ARCoeff-5
# 150              tBodyGyro-ARCoeff-6
# 151              tBodyGyro-ARCoeff-7
# 152              tBodyGyro-ARCoeff-8
# 153              tBodyGyro-ARCoeff-9
# 154             tBodyGyro-ARCoeff-10
# 155             tBodyGyro-ARCoeff-11
# 156             tBodyGyro-ARCoeff-12
# 157          tBodyGyro-Correlation-1
# 158          tBodyGyro-Correlation-2
# 159          tBodyGyro-Correlation-3
# 160             tBodyGyroJerk-Mean-1
# 161             tBodyGyroJerk-Mean-2
# 162             tBodyGyroJerk-Mean-3
# 163              tBodyGyroJerk-STD-1
# 164              tBodyGyroJerk-STD-2
# 165              tBodyGyroJerk-STD-3
# 166              tBodyGyroJerk-Mad-1
# 167              tBodyGyroJerk-Mad-2
# 168              tBodyGyroJerk-Mad-3
# 169              tBodyGyroJerk-Max-1
# 170              tBodyGyroJerk-Max-2
# 171              tBodyGyroJerk-Max-3
# 172              tBodyGyroJerk-Min-1
# 173              tBodyGyroJerk-Min-2
# 174              tBodyGyroJerk-Min-3
# 175              tBodyGyroJerk-SMA-1
# 176           tBodyGyroJerk-Energy-1
# 177           tBodyGyroJerk-Energy-2
# 178           tBodyGyroJerk-Energy-3
# 179              tBodyGyroJerk-IQR-1
# 180              tBodyGyroJerk-IQR-2
# 181              tBodyGyroJerk-IQR-3
# 182             tBodyGyroJerk-ropy-1
# 183             tBodyGyroJerk-ropy-1
# 184             tBodyGyroJerk-ropy-1
# 185          tBodyGyroJerk-ARCoeff-1
# 186          tBodyGyroJerk-ARCoeff-2
# 187          tBodyGyroJerk-ARCoeff-3
# 188          tBodyGyroJerk-ARCoeff-4
# 189          tBodyGyroJerk-ARCoeff-5
# 190          tBodyGyroJerk-ARCoeff-6
# 191          tBodyGyroJerk-ARCoeff-7
# 192          tBodyGyroJerk-ARCoeff-8
# 193          tBodyGyroJerk-ARCoeff-9
# 194         tBodyGyroJerk-ARCoeff-10
# 195         tBodyGyroJerk-ARCoeff-11
# 196         tBodyGyroJerk-ARCoeff-12
# 197      tBodyGyroJerk-Correlation-1
# 198      tBodyGyroJerk-Correlation-2
# 199      tBodyGyroJerk-Correlation-3
# 200               tBodyAccMag-Mean-1
# 201                tBodyAccMag-STD-1
# 202                tBodyAccMag-Mad-1
# 203                tBodyAccMag-Max-1
# 204                tBodyAccMag-Min-1
# 205                tBodyAccMag-SMA-1
# 206             tBodyAccMag-Energy-1
# 207                tBodyAccMag-IQR-1
# 208               tBodyAccMag-ropy-1
# 209            tBodyAccMag-ARCoeff-1
# 210            tBodyAccMag-ARCoeff-2
# 211            tBodyAccMag-ARCoeff-3
# 212            tBodyAccMag-ARCoeff-4
# 213            tGravityAccMag-Mean-1
# 214             tGravityAccMag-STD-1
# 215             tGravityAccMag-Mad-1
# 216             tGravityAccMag-Max-1
# 217             tGravityAccMag-Min-1
# 218             tGravityAccMag-SMA-1
# 219          tGravityAccMag-Energy-1
# 220             tGravityAccMag-IQR-1
# 221            tGravityAccMag-ropy-1
# 222         tGravityAccMag-ARCoeff-1
# 223         tGravityAccMag-ARCoeff-2
# 224         tGravityAccMag-ARCoeff-3
# 225         tGravityAccMag-ARCoeff-4
# 226           tBodyAccJerkMag-Mean-1
# 227            tBodyAccJerkMag-STD-1
# 228            tBodyAccJerkMag-Mad-1
# 229            tBodyAccJerkMag-Max-1
# 230            tBodyAccJerkMag-Min-1
# 231            tBodyAccJerkMag-SMA-1
# 232         tBodyAccJerkMag-Energy-1
# 233            tBodyAccJerkMag-IQR-1
# 234           tBodyAccJerkMag-ropy-1
# 235        tBodyAccJerkMag-ARCoeff-1
# 236        tBodyAccJerkMag-ARCoeff-2
# 237        tBodyAccJerkMag-ARCoeff-3
# 238        tBodyAccJerkMag-ARCoeff-4
# 239              tBodyGyroMag-Mean-1
# 240               tBodyGyroMag-STD-1
# 241               tBodyGyroMag-Mad-1
# 242               tBodyGyroMag-Max-1
# 243               tBodyGyroMag-Min-1
# 244               tBodyGyroMag-SMA-1
# 245            tBodyGyroMag-Energy-1
# 246               tBodyGyroMag-IQR-1
# 247              tBodyGyroMag-ropy-1
# 248           tBodyGyroMag-ARCoeff-1
# 249           tBodyGyroMag-ARCoeff-2
# 250           tBodyGyroMag-ARCoeff-3
# 251           tBodyGyroMag-ARCoeff-4
# 252          tBodyGyroJerkMag-Mean-1
# 253           tBodyGyroJerkMag-STD-1
# 254           tBodyGyroJerkMag-Mad-1
# 255           tBodyGyroJerkMag-Max-1
# 256           tBodyGyroJerkMag-Min-1
# 257           tBodyGyroJerkMag-SMA-1
# 258        tBodyGyroJerkMag-Energy-1
# 259           tBodyGyroJerkMag-IQR-1
# 260          tBodyGyroJerkMag-ropy-1
# 261       tBodyGyroJerkMag-ARCoeff-1
# 262       tBodyGyroJerkMag-ARCoeff-2
# 263       tBodyGyroJerkMag-ARCoeff-3
# 264       tBodyGyroJerkMag-ARCoeff-4
# 265                  fBodyAcc-Mean-1
# 266                  fBodyAcc-Mean-2
# 267                  fBodyAcc-Mean-3
# 268                   fBodyAcc-STD-1
# 269                   fBodyAcc-STD-2
# 270                   fBodyAcc-STD-3
# 271                   fBodyAcc-Mad-1
# 272                   fBodyAcc-Mad-2
# 273                   fBodyAcc-Mad-3
# 274                   fBodyAcc-Max-1
# 275                   fBodyAcc-Max-2
# 276                   fBodyAcc-Max-3
# 277                   fBodyAcc-Min-1
# 278                   fBodyAcc-Min-2
# 279                   fBodyAcc-Min-3
# 280                   fBodyAcc-SMA-1
# 281                fBodyAcc-Energy-1
# 282                fBodyAcc-Energy-2
# 283                fBodyAcc-Energy-3
# 284                   fBodyAcc-IQR-1
# 285                   fBodyAcc-IQR-2
# 286                   fBodyAcc-IQR-3
# 287                  fBodyAcc-ropy-1
# 288                  fBodyAcc-ropy-1
# 289                  fBodyAcc-ropy-1
# 290               fBodyAcc-MaxInds-1
# 291               fBodyAcc-MaxInds-2
# 292               fBodyAcc-MaxInds-3
# 293              fBodyAcc-MeanFreq-1
# 294              fBodyAcc-MeanFreq-2
# 295              fBodyAcc-MeanFreq-3
# 296              fBodyAcc-Skewness-1
# 297              fBodyAcc-Kurtosis-1
# 298              fBodyAcc-Skewness-1
# 299              fBodyAcc-Kurtosis-1
# 300              fBodyAcc-Skewness-1
# 301              fBodyAcc-Kurtosis-1
# 302        fBodyAcc-BandsEnergyOld-1
# 303        fBodyAcc-BandsEnergyOld-2
# 304        fBodyAcc-BandsEnergyOld-3
# 305        fBodyAcc-BandsEnergyOld-4
# 306        fBodyAcc-BandsEnergyOld-5
# 307        fBodyAcc-BandsEnergyOld-6
# 308        fBodyAcc-BandsEnergyOld-7
# 309        fBodyAcc-BandsEnergyOld-8
# 310        fBodyAcc-BandsEnergyOld-9
# 311       fBodyAcc-BandsEnergyOld-10
# 312       fBodyAcc-BandsEnergyOld-11
# 313       fBodyAcc-BandsEnergyOld-12
# 314       fBodyAcc-BandsEnergyOld-13
# 315       fBodyAcc-BandsEnergyOld-14
# 316       fBodyAcc-BandsEnergyOld-15
# 317       fBodyAcc-BandsEnergyOld-16
# 318       fBodyAcc-BandsEnergyOld-17
# 319       fBodyAcc-BandsEnergyOld-18
# 320       fBodyAcc-BandsEnergyOld-19
# 321       fBodyAcc-BandsEnergyOld-20
# 322       fBodyAcc-BandsEnergyOld-21
# 323       fBodyAcc-BandsEnergyOld-22
# 324       fBodyAcc-BandsEnergyOld-23
# 325       fBodyAcc-BandsEnergyOld-24
# 326       fBodyAcc-BandsEnergyOld-25
# 327       fBodyAcc-BandsEnergyOld-26
# 328       fBodyAcc-BandsEnergyOld-27
# 329       fBodyAcc-BandsEnergyOld-28
# 330       fBodyAcc-BandsEnergyOld-29
# 331       fBodyAcc-BandsEnergyOld-30
# 332       fBodyAcc-BandsEnergyOld-31
# 333       fBodyAcc-BandsEnergyOld-32
# 334       fBodyAcc-BandsEnergyOld-33
# 335       fBodyAcc-BandsEnergyOld-34
# 336       fBodyAcc-BandsEnergyOld-35
# 337       fBodyAcc-BandsEnergyOld-36
# 338       fBodyAcc-BandsEnergyOld-37
# 339       fBodyAcc-BandsEnergyOld-38
# 340       fBodyAcc-BandsEnergyOld-39
# 341       fBodyAcc-BandsEnergyOld-40
# 342       fBodyAcc-BandsEnergyOld-41
# 343       fBodyAcc-BandsEnergyOld-42
# 344              fBodyAccJerk-Mean-1
# 345              fBodyAccJerk-Mean-2
# 346              fBodyAccJerk-Mean-3
# 347               fBodyAccJerk-STD-1
# 348               fBodyAccJerk-STD-2
# 349               fBodyAccJerk-STD-3
# 350               fBodyAccJerk-Mad-1
# 351               fBodyAccJerk-Mad-2
# 352               fBodyAccJerk-Mad-3
# 353               fBodyAccJerk-Max-1
# 354               fBodyAccJerk-Max-2
# 355               fBodyAccJerk-Max-3
# 356               fBodyAccJerk-Min-1
# 357               fBodyAccJerk-Min-2
# 358               fBodyAccJerk-Min-3
# 359               fBodyAccJerk-SMA-1
# 360            fBodyAccJerk-Energy-1
# 361            fBodyAccJerk-Energy-2
# 362            fBodyAccJerk-Energy-3
# 363               fBodyAccJerk-IQR-1
# 364               fBodyAccJerk-IQR-2
# 365               fBodyAccJerk-IQR-3
# 366              fBodyAccJerk-ropy-1
# 367              fBodyAccJerk-ropy-1
# 368              fBodyAccJerk-ropy-1
# 369           fBodyAccJerk-MaxInds-1
# 370           fBodyAccJerk-MaxInds-2
# 371           fBodyAccJerk-MaxInds-3
# 372          fBodyAccJerk-MeanFreq-1
# 373          fBodyAccJerk-MeanFreq-2
# 374          fBodyAccJerk-MeanFreq-3
# 375          fBodyAccJerk-Skewness-1
# 376          fBodyAccJerk-Kurtosis-1
# 377          fBodyAccJerk-Skewness-1
# 378          fBodyAccJerk-Kurtosis-1
# 379          fBodyAccJerk-Skewness-1
# 380          fBodyAccJerk-Kurtosis-1
# 381    fBodyAccJerk-BandsEnergyOld-1
# 382    fBodyAccJerk-BandsEnergyOld-2
# 383    fBodyAccJerk-BandsEnergyOld-3
# 384    fBodyAccJerk-BandsEnergyOld-4
# 385    fBodyAccJerk-BandsEnergyOld-5
# 386    fBodyAccJerk-BandsEnergyOld-6
# 387    fBodyAccJerk-BandsEnergyOld-7
# 388    fBodyAccJerk-BandsEnergyOld-8
# 389    fBodyAccJerk-BandsEnergyOld-9
# 390   fBodyAccJerk-BandsEnergyOld-10
# 391   fBodyAccJerk-BandsEnergyOld-11
# 392   fBodyAccJerk-BandsEnergyOld-12
# 393   fBodyAccJerk-BandsEnergyOld-13
# 394   fBodyAccJerk-BandsEnergyOld-14
# 395   fBodyAccJerk-BandsEnergyOld-15
# 396   fBodyAccJerk-BandsEnergyOld-16
# 397   fBodyAccJerk-BandsEnergyOld-17
# 398   fBodyAccJerk-BandsEnergyOld-18
# 399   fBodyAccJerk-BandsEnergyOld-19
# 400   fBodyAccJerk-BandsEnergyOld-20
# 401   fBodyAccJerk-BandsEnergyOld-21
# 402   fBodyAccJerk-BandsEnergyOld-22
# 403   fBodyAccJerk-BandsEnergyOld-23
# 404   fBodyAccJerk-BandsEnergyOld-24
# 405   fBodyAccJerk-BandsEnergyOld-25
# 406   fBodyAccJerk-BandsEnergyOld-26
# 407   fBodyAccJerk-BandsEnergyOld-27
# 408   fBodyAccJerk-BandsEnergyOld-28
# 409   fBodyAccJerk-BandsEnergyOld-29
# 410   fBodyAccJerk-BandsEnergyOld-30
# 411   fBodyAccJerk-BandsEnergyOld-31
# 412   fBodyAccJerk-BandsEnergyOld-32
# 413   fBodyAccJerk-BandsEnergyOld-33
# 414   fBodyAccJerk-BandsEnergyOld-34
# 415   fBodyAccJerk-BandsEnergyOld-35
# 416   fBodyAccJerk-BandsEnergyOld-36
# 417   fBodyAccJerk-BandsEnergyOld-37
# 418   fBodyAccJerk-BandsEnergyOld-38
# 419   fBodyAccJerk-BandsEnergyOld-39
# 420   fBodyAccJerk-BandsEnergyOld-40
# 421   fBodyAccJerk-BandsEnergyOld-41
# 422   fBodyAccJerk-BandsEnergyOld-42
# 423                 fBodyGyro-Mean-1
# 424                 fBodyGyro-Mean-2
# 425                 fBodyGyro-Mean-3
# 426                  fBodyGyro-STD-1
# 427                  fBodyGyro-STD-2
# 428                  fBodyGyro-STD-3
# 429                  fBodyGyro-Mad-1
# 430                  fBodyGyro-Mad-2
# 431                  fBodyGyro-Mad-3
# 432                  fBodyGyro-Max-1
# 433                  fBodyGyro-Max-2
# 434                  fBodyGyro-Max-3
# 435                  fBodyGyro-Min-1
# 436                  fBodyGyro-Min-2
# 437                  fBodyGyro-Min-3
# 438                  fBodyGyro-SMA-1
# 439               fBodyGyro-Energy-1
# 440               fBodyGyro-Energy-2
# 441               fBodyGyro-Energy-3
# 442                  fBodyGyro-IQR-1
# 443                  fBodyGyro-IQR-2
# 444                  fBodyGyro-IQR-3
# 445                 fBodyGyro-ropy-1
# 446                 fBodyGyro-ropy-1
# 447                 fBodyGyro-ropy-1
# 448              fBodyGyro-MaxInds-1
# 449              fBodyGyro-MaxInds-2
# 450              fBodyGyro-MaxInds-3
# 451             fBodyGyro-MeanFreq-1
# 452             fBodyGyro-MeanFreq-2
# 453             fBodyGyro-MeanFreq-3
# 454             fBodyGyro-Skewness-1
# 455             fBodyGyro-Kurtosis-1
# 456             fBodyGyro-Skewness-1
# 457             fBodyGyro-Kurtosis-1
# 458             fBodyGyro-Skewness-1
# 459             fBodyGyro-Kurtosis-1
# 460       fBodyGyro-BandsEnergyOld-1
# 461       fBodyGyro-BandsEnergyOld-2
# 462       fBodyGyro-BandsEnergyOld-3
# 463       fBodyGyro-BandsEnergyOld-4
# 464       fBodyGyro-BandsEnergyOld-5
# 465       fBodyGyro-BandsEnergyOld-6
# 466       fBodyGyro-BandsEnergyOld-7
# 467       fBodyGyro-BandsEnergyOld-8
# 468       fBodyGyro-BandsEnergyOld-9
# 469      fBodyGyro-BandsEnergyOld-10
# 470      fBodyGyro-BandsEnergyOld-11
# 471      fBodyGyro-BandsEnergyOld-12
# 472      fBodyGyro-BandsEnergyOld-13
# 473      fBodyGyro-BandsEnergyOld-14
# 474      fBodyGyro-BandsEnergyOld-15
# 475      fBodyGyro-BandsEnergyOld-16
# 476      fBodyGyro-BandsEnergyOld-17
# 477      fBodyGyro-BandsEnergyOld-18
# 478      fBodyGyro-BandsEnergyOld-19
# 479      fBodyGyro-BandsEnergyOld-20
# 480      fBodyGyro-BandsEnergyOld-21
# 481      fBodyGyro-BandsEnergyOld-22
# 482      fBodyGyro-BandsEnergyOld-23
# 483      fBodyGyro-BandsEnergyOld-24
# 484      fBodyGyro-BandsEnergyOld-25
# 485      fBodyGyro-BandsEnergyOld-26
# 486      fBodyGyro-BandsEnergyOld-27
# 487      fBodyGyro-BandsEnergyOld-28
# 488      fBodyGyro-BandsEnergyOld-29
# 489      fBodyGyro-BandsEnergyOld-30
# 490      fBodyGyro-BandsEnergyOld-31
# 491      fBodyGyro-BandsEnergyOld-32
# 492      fBodyGyro-BandsEnergyOld-33
# 493      fBodyGyro-BandsEnergyOld-34
# 494      fBodyGyro-BandsEnergyOld-35
# 495      fBodyGyro-BandsEnergyOld-36
# 496      fBodyGyro-BandsEnergyOld-37
# 497      fBodyGyro-BandsEnergyOld-38
# 498      fBodyGyro-BandsEnergyOld-39
# 499      fBodyGyro-BandsEnergyOld-40
# 500      fBodyGyro-BandsEnergyOld-41
# 501      fBodyGyro-BandsEnergyOld-42
# 502               fBodyAccMag-Mean-1
# 503                fBodyAccMag-STD-1
# 504                fBodyAccMag-Mad-1
# 505                fBodyAccMag-Max-1
# 506                fBodyAccMag-Min-1
# 507                fBodyAccMag-SMA-1
# 508             fBodyAccMag-Energy-1
# 509                fBodyAccMag-IQR-1
# 510               fBodyAccMag-ropy-1
# 511            fBodyAccMag-MaxInds-1
# 512           fBodyAccMag-MeanFreq-1
# 513           fBodyAccMag-Skewness-1
# 514           fBodyAccMag-Kurtosis-1
# 515           fBodyAccJerkMag-Mean-1
# 516            fBodyAccJerkMag-STD-1
# 517            fBodyAccJerkMag-Mad-1
# 518            fBodyAccJerkMag-Max-1
# 519            fBodyAccJerkMag-Min-1
# 520            fBodyAccJerkMag-SMA-1
# 521         fBodyAccJerkMag-Energy-1
# 522            fBodyAccJerkMag-IQR-1
# 523           fBodyAccJerkMag-ropy-1
# 524        fBodyAccJerkMag-MaxInds-1
# 525       fBodyAccJerkMag-MeanFreq-1
# 526       fBodyAccJerkMag-Skewness-1
# 527       fBodyAccJerkMag-Kurtosis-1
# 528              fBodyGyroMag-Mean-1
# 529               fBodyGyroMag-STD-1
# 530               fBodyGyroMag-Mad-1
# 531               fBodyGyroMag-Max-1
# 532               fBodyGyroMag-Min-1
# 533               fBodyGyroMag-SMA-1
# 534            fBodyGyroMag-Energy-1
# 535               fBodyGyroMag-IQR-1
# 536              fBodyGyroMag-ropy-1
# 537           fBodyGyroMag-MaxInds-1
# 538          fBodyGyroMag-MeanFreq-1
# 539          fBodyGyroMag-Skewness-1
# 540          fBodyGyroMag-Kurtosis-1
# 541          fBodyGyroJerkMag-Mean-1
# 542           fBodyGyroJerkMag-STD-1
# 543           fBodyGyroJerkMag-Mad-1
# 544           fBodyGyroJerkMag-Max-1
# 545           fBodyGyroJerkMag-Min-1
# 546           fBodyGyroJerkMag-SMA-1
# 547        fBodyGyroJerkMag-Energy-1
# 548           fBodyGyroJerkMag-IQR-1
# 549          fBodyGyroJerkMag-ropy-1
# 550       fBodyGyroJerkMag-MaxInds-1
# 551      fBodyGyroJerkMag-MeanFreq-1
# 552      fBodyGyroJerkMag-Skewness-1
# 553      fBodyGyroJerkMag-Kurtosis-1
# 554       tBodyAcc-AngleWRTGravity-1
# 555   tBodyAccJerk-AngleWRTGravity-1
# 556      tBodyGyro-AngleWRTGravity-1
# 557  tBodyGyroJerk-AngleWRTGravity-1
# 558      tXAxisAcc-AngleWRTGravity-1
# 559      tYAxisAcc-AngleWRTGravity-1
# 560      tZAxisAcc-AngleWRTGravity-1

# %%
X_train = pd.read_csv('./data/human_activity/Train/X_train.txt', sep='\s+', header=None)
X_train.columns = features.loc[ : , 'column_name']
X_train
# Out:
# column_name  tBodyAcc-Mean-1  tBodyAcc-Mean-2  tBodyAcc-Mean-3  \
# 0                   0.043580        -0.005970        -0.035054
# 1                   0.039480        -0.002131        -0.029067
# 2                   0.039978        -0.005153        -0.022651
# 3                   0.039785        -0.011809        -0.028916
# 4                   0.038758        -0.002289        -0.023863
# ...                      ...              ...              ...
# 7762                0.048048        -0.042445        -0.065884
# 7763                0.037639         0.006430        -0.044345
# 7764                0.037451        -0.002724         0.021009
# 7765                0.044011        -0.004536        -0.051242
# 7766                0.068954         0.001810        -0.080323
#
# column_name  tBodyAcc-STD-1  tBodyAcc-STD-2  tBodyAcc-STD-3  tBodyAcc-Mad-1  \
# 0                 -0.995381       -0.988366       -0.937382       -0.995007
# 1                 -0.998348       -0.982945       -0.971273       -0.998702
# 2                 -0.995482       -0.977314       -0.984760       -0.996415
# 3                 -0.996194       -0.988569       -0.993256       -0.996994
# 4                 -0.998241       -0.986774       -0.993115       -0.998216
# ...                     ...             ...             ...             ...
# 7762              -0.195448       -0.278326       -0.219954       -0.282233
# 7763              -0.235372       -0.302680       -0.232843       -0.322483
# 7764              -0.218281       -0.378082       -0.076950       -0.304446
# 7765              -0.219202       -0.383350       -0.081035       -0.310419
# 7766              -0.269336       -0.366553       -0.147294       -0.377332
#
# column_name  tBodyAcc-Mad-2  tBodyAcc-Mad-3  tBodyAcc-Max-1  ...  \
# 0                 -0.988816       -0.953325       -0.794796  ...
# 1                 -0.983315       -0.974000       -0.802537  ...
# 2                 -0.975835       -0.985973       -0.798477  ...
# 3                 -0.988526       -0.993135       -0.798477  ...
# 4                 -0.986479       -0.993825       -0.801982  ...
# ...                     ...             ...             ...  ...
# 7762              -0.305861       -0.357803        0.267874  ...
# 7763              -0.354464       -0.345592        0.181271  ...
# 7764              -0.400661       -0.193071        0.113141  ...
# 7765              -0.380233       -0.201007        0.166671  ...
# 7766              -0.360597       -0.255505        0.321881  ...
#
# column_name  fBodyGyroJerkMag-MeanFreq-1  fBodyGyroJerkMag-Skewness-1  \
# 0                              -0.012236                    -0.314848
# 1                               0.202804                    -0.603199
# 2                               0.440079                    -0.404427
# 3                               0.430891                    -0.138373
# 4                               0.137735                    -0.366214
# ...                                  ...                          ...
# 7762                           -0.008381                    -0.596760
# 7763                            0.209452                    -0.404418
# 7764                            0.237003                     0.000207
# 7765                            0.069366                     0.037919
# 7766                            0.002496                    -0.400831
#
# column_name  fBodyGyroJerkMag-Kurtosis-1  tBodyAcc-AngleWRTGravity-1  \
# 0                              -0.713308                   -0.112754
# 1                              -0.860677                    0.053477
# 2                              -0.761847                   -0.118559
# 3                              -0.491604                   -0.036788
# 4                              -0.702490                    0.123320
# ...                                  ...                         ...
# 7762                           -0.879026                   -0.190437
# 7763                           -0.684496                    0.064907
# 7764                           -0.317314                    0.052806
# 7765                           -0.356579                   -0.101360
# 7766                           -0.742972                   -0.280088
#
# column_name  tBodyAccJerk-AngleWRTGravity-1  tBodyGyro-AngleWRTGravity-1  \
# 0                                  0.030400                    -0.464761
# 1                                 -0.007435                    -0.732626
# 2                                  0.177899                     0.100699
# 3                                 -0.012892                     0.640011
# 4                                  0.122542                     0.693578
# ...                                     ...                          ...
# 7762                               0.829718                     0.206972
# 7763                               0.875679                    -0.879033
# 7764                              -0.266724                     0.864404
# 7765                               0.700740                     0.936674
# 7766                              -0.007739                    -0.056088
#
# column_name  tBodyGyroJerk-AngleWRTGravity-1  tXAxisAcc-AngleWRTGravity-1  \
# 0                                  -0.018446                    -0.841559
# 1                                   0.703511                    -0.845092
# 2                                   0.808529                    -0.849230
# 3                                  -0.485366                    -0.848947
# 4                                  -0.615971                    -0.848164
# ...                                      ...                          ...
# 7762                               -0.425619                    -0.792292
# 7763                                0.400219                    -0.772288
# 7764                                0.701169                    -0.779566
# 7765                               -0.589479                    -0.785603
# 7766                               -0.616956                    -0.783693
#
# column_name  tYAxisAcc-AngleWRTGravity-1  tZAxisAcc-AngleWRTGravity-1
# 0                               0.179913                    -0.051718
# 1                               0.180261                    -0.047436
# 2                               0.180610                    -0.042271
# 3                               0.181907                    -0.040826
# 4                               0.185124                    -0.037080
# ...                                  ...                          ...
# 7762                            0.238580                     0.056020
# 7763                            0.252653                     0.056252
# 7764                            0.249121                     0.047071
# 7765                            0.246409                     0.031700
# 7766                            0.246785                     0.042981
#
# [7767 rows x 561 columns]

# %%
X_test = pd.read_csv('./data/human_activity/Test/X_test.txt', sep='\s+', names=feature_list)
X_test.columns = features.loc[ : , 'column_name']
X_test
# Out:
# column_name  tBodyAcc-Mean-1  tBodyAcc-Mean-2  tBodyAcc-Mean-3  \
# 0                   0.030914        -0.008927         0.040382
# 1                   0.042548         0.001079        -0.026236
# 2                   0.038297        -0.011660        -0.025643
# 3                   0.036205        -0.018148        -0.025240
# 4                   0.038034        -0.013437        -0.032899
# ...                      ...              ...              ...
# 3157                0.052279        -0.038687        -0.013494
# 3158                0.073745        -0.024673        -0.017836
# 3159                0.068334         0.043822        -0.024135
# 3160                0.023016         0.032345        -0.011830
# 3161               -0.010846        -0.004134        -0.037678
#
# column_name  tBodyAcc-STD-1  tBodyAcc-STD-2  tBodyAcc-STD-3  tBodyAcc-Mad-1  \
# 0                 -0.938504       -0.944626       -0.759334       -0.952398
# 1                 -0.975516       -0.977502       -0.960146       -0.986694
# 2                 -0.993922       -0.979215       -0.973030       -0.994298
# 3                 -0.994845       -0.981534       -0.976175       -0.995169
# 4                 -0.993955       -0.977493       -0.984290       -0.994006
# ...                     ...             ...             ...             ...
# 3157              -0.287933       -0.403601       -0.431550       -0.356012
# 3158              -0.305455       -0.286487       -0.417996       -0.373468
# 3159              -0.329706       -0.335273       -0.456965       -0.387944
# 3160              -0.323182       -0.465502       -0.426108       -0.392307
# 3161              -0.330114       -0.441542       -0.394796       -0.430898
#
# column_name  tBodyAcc-Mad-2  tBodyAcc-Mad-3  tBodyAcc-Max-1  ...  \
# 0                 -0.950281       -0.802483       -0.757099  ...
# 1                 -0.978983       -0.966820       -0.757099  ...
# 2                 -0.980535       -0.977508       -0.799005  ...
# 3                 -0.983020       -0.980785       -0.798401  ...
# 4                 -0.977354       -0.985899       -0.798401  ...
# ...                     ...             ...             ...  ...
# 3157              -0.433826       -0.534817        0.244280  ...
# 3158              -0.354849       -0.557925        0.244280  ...
# 3159              -0.423504       -0.604403        0.079255  ...
# 3160              -0.520848       -0.569571        0.079255  ...
# 3161              -0.480065       -0.533532       -0.031137  ...
#
# column_name  fBodyGyroJerkMag-MeanFreq-1  fBodyGyroJerkMag-Skewness-1  \
# 0                               0.122830                    -0.345684
# 1                              -0.314688                    -0.142804
# 2                               0.114730                    -0.209525
# 3                               0.164515                    -0.359352
# 4                              -0.056085                    -0.544467
# ...                                  ...                          ...
# 3157                            0.125445                    -0.390349
# 3158                            0.150787                    -0.336001
# 3159                           -0.004765                    -0.139894
# 3160                            0.013540                    -0.224141
# 3161                            0.046926                    -0.094539
#
# column_name  fBodyGyroJerkMag-Kurtosis-1  tBodyAcc-AngleWRTGravity-1  \
# 0                              -0.709087                    0.006462
# 1                              -0.600867                   -0.083495
# 2                              -0.645500                   -0.034956
# 3                              -0.738474                   -0.017067
# 4                              -0.846150                   -0.002223
# ...                                  ...                         ...
# 3157                           -0.752788                   -0.337422
# 3158                           -0.703532                   -0.736701
# 3159                           -0.476335                   -0.181560
# 3160                           -0.623083                    0.444558
# 3161                           -0.446862                    0.598808
#
# column_name  tBodyAccJerk-AngleWRTGravity-1  tBodyGyro-AngleWRTGravity-1  \
# 0                                  0.162920                    -0.825886
# 1                                  0.017500                    -0.434375
# 2                                  0.202302                     0.064103
# 3                                  0.154438                     0.340134
# 4                                 -0.040046                     0.736715
# ...                                     ...                          ...
# 3157                               0.346295                     0.884904
# 3158                              -0.372889                    -0.657421
# 3159                               0.088574                     0.696664
# 3160                              -0.819188                     0.929294
# 3161                              -0.287951                     0.876030
#
# column_name  tBodyGyroJerk-AngleWRTGravity-1  tXAxisAcc-AngleWRTGravity-1  \
# 0                                   0.271151                    -0.720559
# 1                                   0.920593                    -0.698684
# 2                                   0.145068                    -0.703355
# 3                                   0.296407                    -0.699545
# 4                                  -0.118545                    -0.692849
# ...                                      ...                          ...
# 3157                               -0.698885                    -0.652416
# 3158                                0.322548                    -0.655858
# 3159                                0.363139                    -0.656034
# 3160                               -0.008398                    -0.660387
# 3161                               -0.024965                    -0.660748
#
# column_name  tYAxisAcc-AngleWRTGravity-1  tZAxisAcc-AngleWRTGravity-1
# 0                               0.276779                    -0.051074
# 1                               0.281322                    -0.076825
# 2                               0.280062                    -0.072302
# 3                               0.284093                    -0.070079
# 4                               0.290701                    -0.066849
# ...                                  ...                          ...
# 3157                            0.274605                     0.190104
# 3158                            0.273556                     0.187748
# 3159                            0.274457                     0.186527
# 3160                            0.264759                     0.192865
# 3161                            0.263914                     0.193402
#
# [3162 rows x 561 columns]

# %%
# 학습 레이블과 테스트 레이블 데이터를 데이터 프레임으로 로딩, 컬럼명은 target으로 부여
y_train = pd.read_csv('./data/human_activity/Train/y_train.txt', sep='\s+', names=['target'])
y_train
# Out:
#       target
# 0          5
# 1          5
# 2          5
# 3          5
# 4          5
# ...      ...
# 7762       2
# 7763       2
# 7764       2
# 7765       2
# 7766       2
#
# [7767 rows x 1 columns]

# %%
y_test = pd.read_csv('./data/human_activity/Test/y_test.txt', sep='\s+', names=['target'])
y_test
# Out:
#       target
# 0          5
# 1          5
# 2          5
# 3          5
# 4          5
# ...      ...
# 3157       2
# 3158       2
# 3159       2
# 3160       2
# 3161       2
#
# [3162 rows x 1 columns]

# %%
print('## 학습 피처 데이터셋 info()')
X_train.info()
# Out:
# ## 학습 피처 데이터셋 info()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7767 entries, 0 to 7766
# Columns: 561 entries, tBodyAcc-Mean-1 to tZAxisAcc-AngleWRTGravity-1
# dtypes: float64(561)
# memory usage: 33.2 MB

# %%
# target 분포
y_train['target'].value_counts()
# Out:
# 5     1423
# 6     1413
# 4     1293
# 1     1226
# 2     1073
# 3      987
# 11      90
# 9       75
# 10      60
# 12      57
# 7       47
# 8       23
# Name: target, dtype: int64

# %%
# 결측값 확인
X_train.isna().sum().sum()
# Out:
# 0

# %%
tree_model = DecisionTreeClassifier(random_state = 100)
tree_model.fit(X_train , y_train)
y_pred = tree_model.predict(X_test)

acc = accuracy_score(y_test , y_pred)
print('결정트리 분류 정확도 : ' , acc)
print('결정트리 하이퍼 파라미터  : ' , tree_model.get_params() )
# Out:
# 결정트리 분류 정확도 :  0.8020240354206198
# 결정트리 하이퍼 파라미터  :  {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'presort': 'deprecated', 'random_state': 100, 'splitter': 'best'}

# %%
params = {
    'max_depth' : [6, 8, 10, 12, 16, 20, 24]
}

grid_cv = GridSearchCV(tree_model , param_grid = params , scoring='accuracy' , cv=5 , verbose = 1)
grid_cv.fit(X_train , y_train)
print('GS CV 베스트 스코어 : ' , grid_cv.best_score_ )
print('최적의 하이퍼 파라미터  : ' , grid_cv.best_params_ )
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed:  1.7min finished
# GS CV 베스트 스코어 :  0.8433136015235178
# 최적의 하이퍼 파라미터  :  {'max_depth': 10}

# %%
grid_cv_df = pd.DataFrame(grid_cv.cv_results_)
grid_cv_df[['param_max_depth' , 'mean_test_score']]
# Out:
#   param_max_depth  mean_test_score
# 0               6         0.821426
# 1               8         0.842030
# 2              10         0.843314
# 3              12         0.840353
# 4              16         0.836362
# 5              20         0.840354
# 6              24         0.840354

# %%
# 랜덤 포레스트 학습 및 별도의 테스트 셋으로 예측 성능 평가
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train , y_train)
pred = rf_clf.predict(X_test)
accuracy = accuracy_score(y_test , pred)

print('랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))
# Out:
# 랜덤 포레스트 정확도: 0.9108

# %%
params = {
    'n_estimators':[10],
    'max_depth' : [6, 8, 10, 12], 
    'min_samples_leaf' : [8, 12, 18 ],
    'min_samples_split' : [8, 16, 20]
}
# RandomForestClassifier 객체 생성 후 GridSearchCV 수행
rf_clf = RandomForestClassifier(random_state=0, n_jobs=-1)

grid_cv = GridSearchCV(rf_clf , param_grid=params , cv=2, n_jobs=-1 )

grid_cv.fit(X_train , y_train)

print('최적 하이퍼 파라미터:\n', grid_cv.best_params_)
print('최고 예측 정확도: {0:.4f}'.format(grid_cv.best_score_))
# Out:
# 최적 하이퍼 파라미터:
#  {'max_depth': 12, 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 10}
# 최고 예측 정확도: 0.8861

# %%
# 튜닝된 하이퍼 파라미터로 재 학습 및 예측/평가
rf_clf1 = RandomForestClassifier(n_estimators=10, max_depth=12, min_samples_leaf=8, \
                                 min_samples_split=10, random_state=0)
rf_clf1.fit(X_train , y_train)
pred = rf_clf1.predict(X_test)
print('예측 정확도: {0:.4f}'.format(accuracy_score(y_test , pred)))
# Out:
# 예측 정확도: 0.8918

# %%
ftr_importances_values = rf_clf1.feature_importances_
ftr_importances = pd.Series(ftr_importances_values,index=X_train.columns  )
ftr_top20 = ftr_importances.sort_values(ascending=False)[:20]

plt.figure(figsize=(8,6))

sns.barplot(x=ftr_top20 , y = ftr_top20.index)

plt.title('Feature importances Top 20')

plt.show()
plt.close()

# %%
# 중복 데이터 확인
# featureDF[featureDF.duplicated()]
# cumcount() 몇번째 중복된 데이터인지 확인
# featureDF.groupby('column_name').cumcount()
# Out:
#                  column_name
# 23           tBodyAcc-ropy-1
# 24           tBodyAcc-ropy-1
# 63        tGravityAcc-ropy-1
# 64        tGravityAcc-ropy-1
# 103      tBodyAccJerk-ropy-1
# 104      tBodyAccJerk-ropy-1
# 143         tBodyGyro-ropy-1
# 144         tBodyGyro-ropy-1
# 183     tBodyGyroJerk-ropy-1
# 184     tBodyGyroJerk-ropy-1
# 288          fBodyAcc-ropy-1
# 289          fBodyAcc-ropy-1
# 298      fBodyAcc-Skewness-1
# 299      fBodyAcc-Kurtosis-1
# 300      fBodyAcc-Skewness-1
# 301      fBodyAcc-Kurtosis-1
# 367      fBodyAccJerk-ropy-1
# 368      fBodyAccJerk-ropy-1
# 377  fBodyAccJerk-Skewness-1
# 378  fBodyAccJerk-Kurtosis-1
# 379  fBodyAccJerk-Skewness-1
# 380  fBodyAccJerk-Kurtosis-1
# 446         fBodyGyro-ropy-1
# 447         fBodyGyro-ropy-1
# 456     fBodyGyro-Skewness-1
# 457     fBodyGyro-Kurtosis-1
# 458     fBodyGyro-Skewness-1
# 459     fBodyGyro-Kurtosis-1
